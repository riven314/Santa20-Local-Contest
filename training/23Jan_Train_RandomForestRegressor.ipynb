# %%
import os
import joblib

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### 1a. Train, Test Split

# %%
csv_path = '../dataset/topagent_dataset/100_games.csv'
df = pd.read_csv(csv_path)
df.shape
# Out:
# (799600, 7)

# %%
df.head()
# Out:
#    round_num  machine_id  agent_id  n_pulls_self  n_success_self  n_pulls_opp  \
# 0          1          69         0             1               0            0
# 1          1          69         1             0               0            1
# 2          1          94         1             1               0            0
# 3          1          94         0             0               0            1
# 4          2          63         0             1               1            0
#
#    payout
# 0  0.1746
# 1  0.1746
# 2  0.0000
# 3  0.0000
# 4  0.7469

# %%
list(df)
# Out:
# ['round_num',
#  'machine_id',
#  'agent_id',
#  'n_pulls_self',
#  'n_success_self',
#  'n_pulls_opp',
#  'payout']

# %%
predictor_cols = ['round_num', 'n_pulls_self', 'n_success_self', 'n_pulls_opp']
target_col = 'payout'

# %%
df = df.sample(frac = 1, random_state = 0).reset_index(drop = True)

# %%
df.head()
# Out:
#    round_num  machine_id  agent_id  n_pulls_self  n_success_self  n_pulls_opp  \
# 0       1242          38         1            10               5           13
# 1        832          26         1            16               8           14
# 2        141          47         1             6               4            8
# 3       1614          48         0            29              17           18
# 4        648          61         0             2               1            2
#
#      payout
# 0  0.282895
# 1  0.304765
# 2  0.574496
# 3  0.217427
# 4  0.230176

# %%
X = df[predictor_cols]
y = df[target_col]

# %%
X.shape, y.shape
# Out:
# ((799600, 4), (799600,))

# %% [markdown]
# ### 1b. Feature Engineering

# %%
# round_num: group into class
# consecutive k flag

# %% [markdown]
# ### 2a. Grid Search Training
# - Sample Code on grid search:
# ```
# model = RandomForestRegressor()
# grid = GridSearchCV(
#     model, params, cv = 5,
#     scoring = wrapped_r2_score)
# grid.best_params_
# grid.best_score_
# ```
#
# - Sample code on timing train time
# ```
# %%time
# final_rfr = RandomForestRegressor(n_jobs = 10)
# final_rfr.fit(X.head(100000), y.head(100000))
# ```

# %%
sub_df = df.sample(n = 100000, random_state = 0).reset_index(drop = True)
df.shape, sub_df.shape
# Out:
# ((799600, 7), (100000, 7))

# %%
sub_X = sub_df[predictor_cols]
sub_y = sub_df[target_col]

# %%
rfr_params = {
    'criterion': ['mse', 'mae'],
    'max_depth': [3, 6, 9],
    'min_samples_leaf': [2, 0.05, 0.1]
}

# %%
def wrapped_r2_score(estimator, X, y):
    y_pred = estimator.predict(X)
    score = r2_score(y, y_pred)
    return score

# %%
model = RandomForestRegressor()
grid = GridSearchCV(
    model, rfr_params, cv = 4,
    n_jobs = 10, scoring = wrapped_r2_score)

# %%
grid.fit(sub_X, sub_y)
# Out:
# GridSearchCV(cv=4, estimator=RandomForestRegressor(), n_jobs=10,
#              param_grid={'criterion': ['mse', 'mae'], 'max_depth': [3, 6, 9],
#                          'min_samples_leaf': [2, 0.05, 0.1]},
#              scoring=<function wrapped_r2_score at 0x7f0ea19f00e0>)

# %%
pd.DataFrame(grid.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        4.065744      0.486210         0.089635        0.002796
# 1        3.847039      0.436526         0.086831        0.007173
# 2        3.283388      0.195777         0.079746        0.000559
# 3        7.260632      0.146728         0.141156        0.012022
# 4        4.579074      0.183410         0.107166        0.001819
# 5        3.085775      0.236872         0.071044        0.007363
# 6       10.609660      0.223495         0.216681        0.014866
# 7        4.587774      0.399289         0.100969        0.009448
# 8        2.756467      0.386144         0.075922        0.006989
# 9     3232.011759     61.878820         0.087912        0.011828
# 10    2826.704375    157.812001         0.097203        0.001640
# 11    2449.042855     17.806917         0.078761        0.009641
# 12    3683.172717     81.766422         0.135791        0.012216
# 13    3059.356771     83.174969         0.103090        0.002469
# 14    2437.299612     48.954552         0.079991        0.003797
# 15    3790.893672     54.745689         0.203404        0.029891
# 16    2883.408795    116.267212         0.097908        0.010730
# 17    1743.786391    196.498105         0.050988        0.001528
#
#    param_criterion param_max_depth param_min_samples_leaf  \
# 0              mse               3                      2
# 1              mse               3                   0.05
# 2              mse               3                   0.10
# 3              mse               6                      2
# 4              mse               6                   0.05
# 5              mse               6                   0.10
# 6              mse               9                      2
# 7              mse               9                   0.05
# 8              mse               9                   0.10
# 9              mae               3                      2
# 10             mae               3                   0.05
# 11             mae               3                   0.10
# 12             mae               6                      2
# 13             mae               6                   0.05
# 14             mae               6                   0.10
# 15             mae               9                      2
# 16             mae               9                   0.05
# 17             mae               9                   0.10
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'mse', 'max_depth': 3, 'min_samp...           0.603521
# 1   {'criterion': 'mse', 'max_depth': 3, 'min_samp...           0.596575
# 2   {'criterion': 'mse', 'max_depth': 3, 'min_samp...           0.585994
# 3   {'criterion': 'mse', 'max_depth': 6, 'min_samp...           0.656760
# 4   {'criterion': 'mse', 'max_depth': 6, 'min_samp...           0.598243
# 5   {'criterion': 'mse', 'max_depth': 6, 'min_samp...           0.586155
# 6   {'criterion': 'mse', 'max_depth': 9, 'min_samp...           0.686273
# 7   {'criterion': 'mse', 'max_depth': 9, 'min_samp...           0.598153
# 8   {'criterion': 'mse', 'max_depth': 9, 'min_samp...           0.586477
# 9   {'criterion': 'mae', 'max_depth': 3, 'min_samp...           0.597233
# 10  {'criterion': 'mae', 'max_depth': 3, 'min_samp...           0.592582
# 11  {'criterion': 'mae', 'max_depth': 3, 'min_samp...           0.583837
# 12  {'criterion': 'mae', 'max_depth': 6, 'min_samp...           0.645817
# 13  {'criterion': 'mae', 'max_depth': 6, 'min_samp...           0.593326
# 14  {'criterion': 'mae', 'max_depth': 6, 'min_samp...           0.583413
# 15  {'criterion': 'mae', 'max_depth': 9, 'min_samp...           0.678630
# 16  {'criterion': 'mae', 'max_depth': 9, 'min_samp...           0.593633
# 17  {'criterion': 'mae', 'max_depth': 9, 'min_samp...           0.584280
#
#     split1_test_score  split2_test_score  split3_test_score  mean_test_score  \
# 0            0.613286           0.610812           0.613893         0.610378
# 1            0.610304           0.604836           0.608504         0.605055
# 2            0.598276           0.594643           0.597640         0.594138
# 3            0.665204           0.656502           0.665516         0.660996
# 4            0.611226           0.605757           0.609936         0.606291
# 5            0.598293           0.594596           0.597198         0.594060
# 6            0.693511           0.686353           0.692248         0.689596
# 7            0.611472           0.605716           0.609863         0.606301
# 8            0.598467           0.593975           0.597567         0.594122
# 9            0.612956           0.603020           0.613049         0.606565
# 10           0.610410           0.600230           0.609045         0.603067
# 11           0.596626           0.592637           0.597508         0.592652
# 12           0.654442           0.645302           0.656037         0.650399
# 13           0.610969           0.600705           0.610287         0.603822
# 14           0.596668           0.592815           0.597466         0.592591
# 15           0.685049           0.675089           0.684754         0.680881
# 16           0.610817           0.601106           0.610083         0.603910
# 17           0.597165           0.592846           0.597057         0.592837
#
#     std_test_score  rank_test_score
# 0         0.004124                5
# 1         0.005277                9
# 2         0.004898               13
# 3         0.004367                3
# 4         0.005067                8
# 5         0.004758               15
# 6         0.003314                1
# 7         0.005152                7
# 8         0.004723               14
# 9         0.006755                6
# 10        0.007205               12
# 11        0.005410               17
# 12        0.004876                4
# 13        0.007293               11
# 14        0.005583               18
# 15        0.004213                2
# 16        0.007058               10
# 17        0.005238               16

# %%
grid.best_params_
# Out:
# {'criterion': 'mse', 'max_depth': 9, 'min_samples_leaf': 2}

# %%
# train avg scores v.s. test avg scores

# %% [markdown]
# ### 2b. Cross Validation on Full Dataset with Best Param

# %% [markdown]
# ### 3. Retrain with Best Param and Save Models

# %%
best_params = grid.best_params_

# %%
final_rfr = RandomForestRegressor(**best_params)
final_rfr.fit(X, y)
# Out:
# RandomForestRegressor(max_depth=9, min_samples_leaf=2)

# %%
joblib.dump(final_rfr, '100games_rfr.joblib')
# Out:
# ['100games_rfr.joblib']
